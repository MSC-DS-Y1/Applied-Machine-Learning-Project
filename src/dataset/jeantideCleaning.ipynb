# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('uncleaned_dataset.csv', sep=';')
data.head()

#test
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# 2                           122.0            1                      37
# 3                           122.0            1                      38
# 4                           100.0            1                      37
#
#    Father's qualification  ...  Curricular units 2nd sem (credited)  \
# 0                      12  ...                                    0
# 1                       3  ...                                    0
# 2                      37  ...                                    0
# 3                      37  ...                                    0
# 4                      38  ...                                    0
#
#    Curricular units 2nd sem (enrolled)  \
# 0                                    0
# 1                                    6
# 2                                    6
# 3                                    6
# 4                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
# 3                                      10
# 4                                       6
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
# 3                                    5                         12.400000
# 4                                    6                         13.000000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
# 3                                               0                9.4
# 4                                               0               13.9
#
#    Inflation rate   GDP    Target
# 0             1.4  1.74   Dropout
# 1            -0.3  0.79  Graduate
# 2             1.4  1.74   Dropout
# 3            -0.8 -3.12  Graduate
# 4            -0.3  0.79  Graduate
#
# [5 rows x 37 columns]

# %%
data.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571         18.669078           1.727848  8856.642631
# std          0.605747         17.484682           1.313793  2063.566416
# min          1.000000          1.000000           0.000000    33.000000
# 25%          1.000000          1.000000           1.000000  9085.000000
# 50%          1.000000         17.000000           1.000000  9238.000000
# 75%          1.000000         39.000000           2.000000  9556.000000
# max          6.000000         57.000000           9.000000  9991.000000
#
#        Daytime/evening attendance\t  Previous qualification  \
# count                   4424.000000             4424.000000
# mean                       0.890823                4.577758
# std                        0.311897               10.216592
# min                        0.000000                1.000000
# 25%                        1.000000                1.000000
# 50%                        1.000000                1.000000
# 75%                        1.000000                1.000000
# max                        1.000000               43.000000
#
#        Previous qualification (grade)  Nacionality  Mother's qualification  \
# count                     4424.000000  4424.000000             4424.000000
# mean                       132.613314     1.873192               19.561935
# std                         13.188332     6.914514               15.603186
# min                         95.000000     1.000000                1.000000
# 25%                        125.000000     1.000000                2.000000
# 50%                        133.100000     1.000000               19.000000
# 75%                        140.000000     1.000000               37.000000
# max                        190.000000   109.000000               44.000000
#
#        Father's qualification  ...  \
# count             4424.000000  ...
# mean                22.275316  ...
# std                 15.343108  ...
# min                  1.000000  ...
# 25%                  3.000000  ...
# 50%                 19.000000  ...
# 75%                 37.000000  ...
# max                 44.000000  ...
#
#        Curricular units 1st sem (without evaluations)  \
# count                                     4424.000000
# mean                                         0.137658
# std                                          0.690880
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                         12.000000
#
#        Curricular units 2nd sem (credited)  \
# count                          4424.000000
# mean                              0.541817
# std                               1.918546
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                              19.000000
#
#        Curricular units 2nd sem (enrolled)  \
# count                          4424.000000
# mean                              6.232143
# std                               2.195951
# min                               0.000000
# 25%                               5.000000
# 50%                               6.000000
# 75%                               7.000000
# max                              23.000000
#
#        Curricular units 2nd sem (evaluations)  \
# count                             4424.000000
# mean                                 8.063291
# std                                  3.947951
# min                                  0.000000
# 25%                                  6.000000
# 50%                                  8.000000
# 75%                                 10.000000
# max                                 33.000000
#
#        Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# count                          4424.000000                       4424.000000
# mean                              4.435805                         10.230206
# std                               3.014764                          5.210808
# min                               0.000000                          0.000000
# 25%                               2.000000                         10.750000
# 50%                               5.000000                         12.200000
# 75%                               6.000000                         13.333333
# max                              20.000000                         18.571429
#
#        Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# count                                     4424.000000        4424.000000
# mean                                         0.150316          11.566139
# std                                          0.753774           2.663850
# min                                          0.000000           7.600000
# 25%                                          0.000000           9.400000
# 50%                                          0.000000          11.100000
# 75%                                          0.000000          13.900000
# max                                         12.000000          16.200000
#
#        Inflation rate          GDP
# count     4424.000000  4424.000000
# mean         1.228029     0.001969
# std          1.382711     2.269935
# min         -0.800000    -4.060000
# 25%          0.300000    -1.700000
# 50%          1.400000     0.320000
# 75%          2.600000     1.790000
# max          3.700000     3.510000
#
# [8 rows x 36 columns]

# %%
#rename the columns to remove spaces
data.columns= ["Marital_status", "Application_mode", "Application_order", "Course", "Daytime_evening_attendance", "Previous_qualif", "Previous_qualif_grade", "Nationality", "Mother_qualif", "Father_qualif", "Mother_occ", "Father_occ", "Admission_grade", "Displaced", "SEN", "Debtor", "Tuition_fees_up_to_date", "Gender", "Scholarship", "Age_at_enrollment", "International", "Units_1_credited", "Units_1_enrolled", "Units_1_evaluations", "Units_1_approved", "Units_1_grade", "Units_1_no_evaluations", "Units_2_credited", "Units_2_enrolled", "Units_2_evaluations", "Units_2_approved", "Units_2_grade", "Units_2_no_evaluations", "Unemployment_rate", "Inflation_rate", "GDP", "Target"]

#checking for null values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Marital_status              4424 non-null   int64
#  1   Application_mode            4424 non-null   int64
#  2   Application_order           4424 non-null   int64
#  3   Course                      4424 non-null   int64
#  4   Daytime_evening_attendance  4424 non-null   int64
#  5   Previous_qualif             4424 non-null   int64
#  6   Previous_qualif_grade       4424 non-null   float64
#  7   Nationality                 4424 non-null   int64
#  8   Mother_qualif               4424 non-null   int64
#  9   Father_qualif               4424 non-null   int64
#  10  Mother_occ                  4424 non-null   int64
#  11  Father_occ                  4424 non-null   int64
#  12  Admission_grade             4424 non-null   float64
#  13  Displaced                   4424 non-null   int64
#  14  SEN                         4424 non-null   int64
#  15  Debtor                      4424 non-null   int64
#  16  Tuition_fees_up_to_date     4424 non-null   int64
#  17  Gender                      4424 non-null   int64
#  18  Scholarship                 4424 non-null   int64
#  19  Age_at_enrollment           4424 non-null   int64
#  20  International               4424 non-null   int64
#  21  Units_1_credited            4424 non-null   int64
#  22  Units_1_enrolled            4424 non-null   int64
#  23  Units_1_evaluations         4424 non-null   int64
#  24  Units_1_approved            4424 non-null   int64
#  25  Units_1_grade               4424 non-null   float64
#  26  Units_1_no_evaluations      4424 non-null   int64
#  27  Units_2_credited            4424 non-null   int64
#  28  Units_2_enrolled            4424 non-null   int64
#  29  Units_2_evaluations         4424 non-null   int64
#  30  Units_2_approved            4424 non-null   int64
#  31  Units_2_grade               4424 non-null   float64
#  32  Units_2_no_evaluations      4424 non-null   int64
#  33  Unemployment_rate           4424 non-null   float64
#  34  Inflation_rate              4424 non-null   float64
#  35  GDP                         4424 non-null   float64
#  36  Target                      4424 non-null   object
# dtypes: float64(7), int64(29), object(1)
# memory usage: 1.2+ MB

# %%
#independent variables
x_vars = data.drop("Target", axis = 1)

#dependent target variable
y_vars = data["Target"] # target is descrete - classification

# %%
#plotting the dependent variables as histograms to ensure discrete or continuous
num_vars = x_vars.shape[1]
rows, cols = 6, 6  # A 6x6 grid for 36 histograms

# Create a figure with a specified size
fig, axes = plt.subplots(rows, cols, figsize=(18, 18))

# Flatten axes array for easy iteration
axes = axes.flatten()

# Loop through each variable and plot its histogram
for i, column in enumerate(x_vars.columns):
    axes[i].hist(x_vars[column], bins = 30, edgecolor='black')  
    axes[i].set_title(column)
    axes[i].set_xlabel('Value')
    axes[i].set_ylabel('Frequency')

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
#Target distribution
data["Target"].hist()
# Out:
# <Axes: >

# %% [markdown]
# Mutual information feature selection - for redundant features

# %% [markdown]
# Calculate the mutual information score on each of the 20 selected input variables in comparison with the target vector. The higher the input variable, the better related to the target value.

# %%
#see if x is descrete or continuous
discrete_features = x_vars.dtypes == "int64" 
#discrete_features['Age_at_enrollment'] = False #change this manually to ensure age is seen as a continuous variable
#previously had set this as continuous, but it might be better if this is set as categorical as in the dataset definitions?

from sklearn.feature_selection import mutual_info_classif, mutual_info_regression

def make_mi_scores(X, y, discrete_features):
    mi_scores = mutual_info_classif(X, y, discrete_features=discrete_features, random_state=42) # assigning whether the x_variable is descrete or continuous, always keeping the random state consistent for the same results from one iteration to another
    mi_scores = pd.Series(mi_scores, name = "MI Scores", index = X.columns)
    mi_scores = mi_scores.sort_values(ascending = False)
    return mi_scores

mi_scores = make_mi_scores(x_vars, y_vars,discrete_features)

print(mi_scores)

def plot_mi_scores(scores):
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.barh(width, scores)
    plt.yticks(width, ticks)
    plt.title("Mutual Information Scores with Target")


plt.figure(dpi=100, figsize=(8, 5))
plot_mi_scores(mi_scores)
# Out:
# Units_2_approved              0.316069
# Units_1_approved              0.246978
# Units_2_grade                 0.236154
# Units_1_grade                 0.187769
# Units_2_evaluations           0.096403
# Tuition_fees_up_to_date       0.091828
# Units_1_evaluations           0.090263
# Course                        0.066468
# Age_at_enrollment             0.062007
# Application_mode              0.052221
# Units_2_enrolled              0.050366
# Units_1_enrolled              0.050234
# Scholarship                   0.049156
# Mother_occ                    0.034022
# Admission_grade               0.033884
# Father_occ                    0.030819
# Debtor                        0.028939
# Previous_qualif_grade         0.027180
# Gender                        0.026415
# Father_qualif                 0.026018
# Mother_qualif                 0.024848
# Previous_qualif               0.024626
# Application_order             0.007897
# Units_1_credited              0.007558
# Units_2_no_evaluations        0.007435
# Units_1_no_evaluations        0.007199
# Units_2_credited              0.006948
# Marital_status                0.006791
# Displaced                     0.006526
# Nationality                   0.005808
# Daytime_evening_attendance    0.003117
# Unemployment_rate             0.001994
# International                 0.000139
# SEN                           0.000071
# Inflation_rate                0.000000
# GDP                           0.000000
# Name: MI Scores, dtype: float64

# %% [markdown]
# For irrelevant features, need to calculate the pairwise mutual information .
# High Mutual information scores for pairs of variables means that they provide similar information to the dataset and some can be removed

# %%
x_vars.shape[1]

def pairwise_mi(df, discrete_features):
    n = df.shape[1]
    mi_matrix = np.zeros((n,n))
    
    for i in range(n):
        for j in range(n):
            #start with equal pairs and mark is not applicable
            if i == j:
                mi_matrix[i,j] = np.nan
            else:
                x = df.iloc[:,i]
                y = df.iloc[:,j]
                
                #first case: if both variables are discrete
                if discrete_features[i] and discrete_features[j]:
                    mi = mutual_info_classif(x.values.reshape(-1,1), y.values, discrete_features = True, random_state=42)[0]
                #now if both variables are continuous
                elif not discrete_features[i] and not discrete_features[j]:
                    mi = mutual_info_regression(x.values.reshape(-1,1), y.values, discrete_features=False, random_state=42)[0]
                #now one is continuous and another is discrete- prefer to take a regression case than a classification case, leaving descrete_feature as auto in this case
                else:
                    mi = mutual_info_regression(x.values.reshape(-1,1), y.values, random_state=42)[0]
                
                mi_matrix[i,j] = mi
    return pd.DataFrame(mi_matrix,index = df.columns, columns = df.columns)
                


#generate pairwise MI matrix
mi_matrix = pairwise_mi(x_vars, discrete_features)
# Out:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# ...
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not discrete_features[i] and not discrete_features[j]:

# %%
#Equalise the values
from sklearn.preprocessing import MinMaxScaler, StandardScaler

def equaliseMatrices(df): 
    # Min-Max Scaling (values between 0 and 1)
    scaler = MinMaxScaler()
    df_minmax = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

    # Standard Scaling (zero mean, unit variance)
    scaler = StandardScaler()
    df_standard = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

    return df_minmax, df_standard

equalisedDfMinmax, equalisedDfStandard = equaliseMatrices(x_vars)

# %%
x_vars.shape[1]

def nonDiscretepairwise(df):
    n = df.shape[1]
    mi_matrix = np.zeros((n,n))
    
    for i in range(n):
        for j in range(n):
            #start with equal pairs and mark is not applicable
            if i == j:
                mi_matrix[i,j] = np.nan
            else:
                x = df.iloc[:,i]
                y = df.iloc[:,j]
                
                mi = mutual_info_regression(x.values.reshape(-1, 1), y.values, random_state=42)[0]
                
                mi_matrix[i,j] = mi
    return pd.DataFrame(mi_matrix,index = df.columns, columns = df.columns)
                
minMax_Matrix = nonDiscretepairwise(equalisedDfMinmax)
standard_Matrix = nonDiscretepairwise(equalisedDfStandard)
# Out:
# C:\Users\gianl\AppData\Local\Temp\ipykernel_4320\2603991204.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if discrete_features[i] and discrete_features[j]:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 4
#       1 minMaxDiscrete_features = equalisedDfMinmax.dtypes == "int64"
#       2 standardDiscrete_features = equalisedDfStandard.dtypes == "int64"
# ----> 4 minMax_Matrix = pairwise_mi(equalisedDfMinmax, discrete_features)
#       5 standard_Matrix = pairwise_mi(equalisedDfStandard, discrete_features)
#
# Cell In[9], line 18, in pairwise_mi(df, discrete_features)
#      16 #first case: if both variables are discrete
#      17 if discrete_features[i] and discrete_features[j]:
# ---> 18     mi = mutual_info_classif(x.values.reshape(-1,1), y.values, discrete_features = True, random_state=42)[0]
#      19 #now if both variables are continuous
#      20 elif not discrete_features[i] and not discrete_features[j]:
#
# File c:\Users\gianl\anaconda3\envs\MachineLearningEnv\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\gianl\anaconda3\envs\MachineLearningEnv\Lib\site-packages\sklearn\feature_selection\_mutual_info.py:570, in mutual_info_classif(X, y, discrete_features, n_neighbors, copy, random_state, n_jobs)
#     453 @validate_params(
#     454     {
#     455         "X": ["array-like", "sparse matrix"],
#    (...)
#     473     n_jobs=None,
#     474 ):
#     475     """Estimate mutual information for a discrete target variable.
#     476
#     477     Mutual information (MI) [1]_ between two random variables is a non-negative
#    (...)
#     568            0.     , 0.     , 0.     , 0.      , 0.        ])
#     569     """
# --> 570     check_classification_targets(y)
#     571     return _estimate_mi(
#     572         X,
#     573         y,
#    (...)
#     579         n_jobs=n_jobs,
#     580     )
#
# File c:\Users\gianl\anaconda3\envs\MachineLearningEnv\Lib\site-packages\sklearn\utils\multiclass.py:219, in check_classification_targets(y)
#     211 y_type = type_of_target(y, input_name="y")
#     212 if y_type not in [
#     213     "binary",
#     214     "multiclass",
#    (...)
#     217     "multilabel-sequences",
#     218 ]:
# --> 219     raise ValueError(
#     220         f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     221         "classifier, which expects discrete classes on a "
#     222         "regression target with continuous values."
#     223     )
#
# ValueError: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.

# %%
# Create a 1-row, 2-column layout for the two matrices
fig, axes = plt.subplots(1, 2, figsize=(12, 6))  # (rows, columns)

# Plot the first matrix
im1 = axes[0].imshow(minMax_Matrix, cmap = "plasma", interpolation = "nearest", origin = "upper")
axes[0].set_title('Equalised Matrix (MinMax)')

# Plot the second matrix
im2 = axes[1].imshow(standard_Matrix, cmap = "plasma", interpolation = "nearest", origin = "upper")
axes[1].set_title('Equalised Matrix (Standard)')

# Display the plots
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       2 fig, axes = plt.subplots(1, 2, figsize=(12, 6))  # (rows, columns)
#       4 # Plot the first matrix
# ----> 5 im1 = axes[0].imshow(minMax_Matrix, cmap = "plasma", interpolation = "nearest", origin = "upper")
#       6 axes[0].set_title('Equalised Matrix (MinMax)')
#       8 # Plot the second matrix
#
# NameError: name 'minMax_Matrix' is not defined

# %%
#plotting the pairwise mi scores to visualise in a heatmap

plt.figure(figsize = (10,10))
plt.imshow(mi_matrix, cmap = "plasma", interpolation = "nearest", origin = "upper")
#plt.colorbar(label="Mutual Information")

labels = x_vars.columns

plt.xticks(ticks=np.arange(len(labels)), labels=labels, rotation=45, ha="right", fontsize=10)
plt.yticks(ticks=np.arange(len(labels)), labels=labels, fontsize=10)
plt.title("Pairwise Mutual Information Heatmap", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# A threshold for the Target MI scores can be assigned based on the values in the plot
# Similarly, a threshold based on the MI matrix values can be assigned for the pairwise MI scores.
#
# The final variables to be kept are those which first meet the MI Target threshold, and then the pairwise MI threshold.

# %%
#setting the thresholds, these can be altered
mi_threshold_target = 0.02
mi_threshold_pairwise = 0.5


relevant_features = [col for col in mi_scores.index if mi_scores[col] > mi_threshold_target]
print(f"Relevant features based on target MI: {relevant_features}")

remaining_features = relevant_features.copy()


features_to_drop = []

# Check pairwise MI between remaining features
for i in range(len(remaining_features)):
    for j in range(i + 1, len(remaining_features)):
        # If pairwise MI is above the threshold, drop one feature
        mi_value = mi_matrix.loc[remaining_features[i], remaining_features[j]]
        if mi_value > mi_threshold_pairwise:
            features_to_drop.append(remaining_features[j])

final_features = [feature for feature in remaining_features if feature not in features_to_drop]
print(f"Final selected features: {final_features}")
# Out:
# Relevant features based on target MI: ['Units_2_approved', 'Units_1_approved', 'Units_2_grade', 'Units_1_grade', 'Units_2_evaluations', 'Tuition_fees_up_to_date', 'Units_1_evaluations', 'Course', 'Age_at_enrollment', 'Application_mode', 'Units_2_enrolled', 'Units_1_enrolled', 'Scholarship', 'Mother_occ', 'Admission_grade', 'Father_occ', 'Debtor', 'Previous_qualif_grade', 'Gender', 'Father_qualif', 'Mother_qualif', 'Previous_qualif']
# Final selected features: ['Units_2_approved', 'Tuition_fees_up_to_date', 'Course', 'Age_at_enrollment', 'Scholarship', 'Mother_occ', 'Admission_grade', 'Debtor', 'Gender', 'Father_qualif', 'Mother_qualif', 'Previous_qualif']

# %% [markdown]
# Need to double check MI Matrix calculations, I am not convinced the calculations are correct
